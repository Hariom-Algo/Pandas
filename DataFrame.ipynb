# %%
import pandas as pd
nba= pd.read_csv("nba.csv")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ## Difference between Shared Methods

# %%
pd.read_csv("revenue.csv", index_col = "Date")
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
rev= pd.read_csv("revenue.csv", index_col = "Date")

# %%
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1,2,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.sum()
# Out:
# 6

# %%
s.sum(axis=0)
# Out:
# 6

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
# Not good for columns with whitespaces 
rev.Miami
# Out:
# Date
# 1/1/16     499
# 1/2/16     534
# 1/3/16     933
# 1/4/16     885
# 1/5/16     253
# 1/6/16     497
# 1/7/16     115
# 1/8/16     886
# 1/9/16     823
# 1/10/16    216
# Name: Miami, dtype: int64

# %%
rev["New York"]
# Out:
# Date
# 1/1/16     985
# 1/2/16     738
# 1/3/16      14
# 1/4/16     730
# 1/5/16     114
# 1/6/16     936
# 1/7/16     123
# 1/8/16     935
# 1/9/16     846
# 1/10/16     54
# Name: New York, dtype: int64

# %%
# Returns series 
type(rev["New York"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Select Two or More Columns from A DataFrame

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba[["Name","Team"]]
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# 17           Wayne Ellington           Brooklyn Nets
# 18   Rondae Hollis-Jefferson           Brooklyn Nets
# 19              Jarrett Jack           Brooklyn Nets
# 20            Sergey Karasev           Brooklyn Nets
# 21           Sean Kilpatrick           Brooklyn Nets
# 22              Shane Larkin           Brooklyn Nets
# 23               Brook Lopez           Brooklyn Nets
# 24          Chris McCullough           Brooklyn Nets
# 25               Willie Reed           Brooklyn Nets
# 26           Thomas Robinson           Brooklyn Nets
# 27                Henry Sims           Brooklyn Nets
# 28              Donald Sloan           Brooklyn Nets
# 29            Thaddeus Young           Brooklyn Nets
# ..                       ...                     ...
# 428          Al-Farouq Aminu  Portland Trail Blazers
# 429          Pat Connaughton  Portland Trail Blazers
# 430             Allen Crabbe  Portland Trail Blazers
# 431                 Ed Davis  Portland Trail Blazers
# 432         Maurice Harkless  Portland Trail Blazers
# 433         Gerald Henderson  Portland Trail Blazers
# 434              Chris Kaman  Portland Trail Blazers
# 435           Meyers Leonard  Portland Trail Blazers
# 436           Damian Lillard  Portland Trail Blazers
# 437            C.J. McCollum  Portland Trail Blazers
# 438             Luis Montero  Portland Trail Blazers
# 439            Mason Plumlee  Portland Trail Blazers
# 440            Brian Roberts  Portland Trail Blazers
# 441              Noah Vonleh  Portland Trail Blazers
# 442            Trevor Booker               Utah Jazz
# 443               Trey Burke               Utah Jazz
# 444               Alec Burks               Utah Jazz
# 445               Dante Exum               Utah Jazz
# 446           Derrick Favors               Utah Jazz
# 447              Rudy Gobert               Utah Jazz
# 448           Gordon Hayward               Utah Jazz
# 449              Rodney Hood               Utah Jazz
# 450               Joe Ingles               Utah Jazz
# 451            Chris Johnson               Utah Jazz
# 452               Trey Lyles               Utah Jazz
# 453             Shelvin Mack               Utah Jazz
# 454                Raul Neto               Utah Jazz
# 455             Tibor Pleiss               Utah Jazz
# 456              Jeff Withey               Utah Jazz
# 457                      NaN                     NaN
#
# [458 rows x 2 columns]

# %%
type(nba[["Name","Team"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Can reverse the order
nba[["Team","Name"]]
# Out:
#                        Team                     Name
# 0            Boston Celtics            Avery Bradley
# 1            Boston Celtics              Jae Crowder
# 2            Boston Celtics             John Holland
# 3            Boston Celtics              R.J. Hunter
# 4            Boston Celtics            Jonas Jerebko
# 5            Boston Celtics             Amir Johnson
# 6            Boston Celtics            Jordan Mickey
# 7            Boston Celtics             Kelly Olynyk
# 8            Boston Celtics             Terry Rozier
# 9            Boston Celtics             Marcus Smart
# 10           Boston Celtics          Jared Sullinger
# 11           Boston Celtics            Isaiah Thomas
# 12           Boston Celtics              Evan Turner
# 13           Boston Celtics              James Young
# 14           Boston Celtics             Tyler Zeller
# 15            Brooklyn Nets         Bojan Bogdanovic
# 16            Brooklyn Nets             Markel Brown
# 17            Brooklyn Nets          Wayne Ellington
# 18            Brooklyn Nets  Rondae Hollis-Jefferson
# 19            Brooklyn Nets             Jarrett Jack
# 20            Brooklyn Nets           Sergey Karasev
# 21            Brooklyn Nets          Sean Kilpatrick
# 22            Brooklyn Nets             Shane Larkin
# 23            Brooklyn Nets              Brook Lopez
# 24            Brooklyn Nets         Chris McCullough
# 25            Brooklyn Nets              Willie Reed
# 26            Brooklyn Nets          Thomas Robinson
# 27            Brooklyn Nets               Henry Sims
# 28            Brooklyn Nets             Donald Sloan
# 29            Brooklyn Nets           Thaddeus Young
# ..                      ...                      ...
# 428  Portland Trail Blazers          Al-Farouq Aminu
# 429  Portland Trail Blazers          Pat Connaughton
# 430  Portland Trail Blazers             Allen Crabbe
# 431  Portland Trail Blazers                 Ed Davis
# 432  Portland Trail Blazers         Maurice Harkless
# 433  Portland Trail Blazers         Gerald Henderson
# 434  Portland Trail Blazers              Chris Kaman
# 435  Portland Trail Blazers           Meyers Leonard
# 436  Portland Trail Blazers           Damian Lillard
# 437  Portland Trail Blazers            C.J. McCollum
# 438  Portland Trail Blazers             Luis Montero
# 439  Portland Trail Blazers            Mason Plumlee
# 440  Portland Trail Blazers            Brian Roberts
# 441  Portland Trail Blazers              Noah Vonleh
# 442               Utah Jazz            Trevor Booker
# 443               Utah Jazz               Trey Burke
# 444               Utah Jazz               Alec Burks
# 445               Utah Jazz               Dante Exum
# 446               Utah Jazz           Derrick Favors
# 447               Utah Jazz              Rudy Gobert
# 448               Utah Jazz           Gordon Hayward
# 449               Utah Jazz              Rodney Hood
# 450               Utah Jazz               Joe Ingles
# 451               Utah Jazz            Chris Johnson
# 452               Utah Jazz               Trey Lyles
# 453               Utah Jazz             Shelvin Mack
# 454               Utah Jazz                Raul Neto
# 455               Utah Jazz             Tibor Pleiss
# 456               Utah Jazz              Jeff Withey
# 457                     NaN                      NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# # Add New Column to DataFrame

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Sport"] = "Basketball"

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 445               Dante Exum               Utah Jazz    11.0       PG  20.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 457                      NaN                     NaN     NaN      NaN   NaN
#
#     Height  Weight            College      Salary       Sport
# 0      6-2   180.0              Texas   7730337.0  Basketball
# 1      6-6   235.0          Marquette   6796117.0  Basketball
# 2      6-5   205.0  Boston University         NaN  Basketball
# 3      6-5   185.0      Georgia State   1148640.0  Basketball
# 4     6-10   231.0                NaN   5000000.0  Basketball
# 5      6-9   240.0                NaN  12000000.0  Basketball
# 6      6-8   235.0                LSU   1170960.0  Basketball
# 7      7-0   238.0            Gonzaga   2165160.0  Basketball
# 8      6-2   190.0         Louisville   1824360.0  Basketball
# 9      6-4   220.0     Oklahoma State   3431040.0  Basketball
# 10     6-9   260.0         Ohio State   2569260.0  Basketball
# 11     5-9   185.0         Washington   6912869.0  Basketball
# 12     6-7   220.0         Ohio State   3425510.0  Basketball
# 13     6-6   215.0           Kentucky   1749840.0  Basketball
# 14     7-0   253.0     North Carolina   2616975.0  Basketball
# 15     6-8   216.0                NaN   3425510.0  Basketball
# 16     6-3   190.0     Oklahoma State    845059.0  Basketball
# 17     6-4   200.0     North Carolina   1500000.0  Basketball
# 18     6-7   220.0            Arizona   1335480.0  Basketball
# 19     6-3   200.0       Georgia Tech   6300000.0  Basketball
# 20     6-7   208.0                NaN   1599840.0  Basketball
# 21     6-4   219.0         Cincinnati    134215.0  Basketball
# 22    5-11   175.0         Miami (FL)   1500000.0  Basketball
# 23     7-0   275.0           Stanford  19689000.0  Basketball
# 24    6-11   200.0           Syracuse   1140240.0  Basketball
# 25    6-10   220.0        Saint Louis    947276.0  Basketball
# 26    6-10   237.0             Kansas    981348.0  Basketball
# 27    6-10   248.0         Georgetown    947276.0  Basketball
# 28     6-3   205.0          Texas A&M    947276.0  Basketball
# 29     6-8   221.0       Georgia Tech  11235955.0  Basketball
# ..     ...     ...                ...         ...         ...
# 428    6-9   215.0        Wake Forest   8042895.0  Basketball
# 429    6-5   206.0         Notre Dame    625093.0  Basketball
# 430    6-6   210.0         California    947276.0  Basketball
# 431   6-10   240.0     North Carolina   6980802.0  Basketball
# 432    6-9   215.0         St. John's   2894059.0  Basketball
# 433    6-5   215.0               Duke   6000000.0  Basketball
# 434    7-0   265.0   Central Michigan   5016000.0  Basketball
# 435    7-1   245.0           Illinois   3075880.0  Basketball
# 436    6-3   195.0        Weber State   4236287.0  Basketball
# 437    6-4   200.0             Lehigh   2525160.0  Basketball
# 438    6-7   185.0     Westchester CC    525093.0  Basketball
# 439   6-11   235.0               Duke   1415520.0  Basketball
# 440    6-1   173.0             Dayton   2854940.0  Basketball
# 441    6-9   240.0            Indiana   2637720.0  Basketball
# 442    6-8   228.0            Clemson   4775000.0  Basketball
# 443    6-1   191.0           Michigan   2658240.0  Basketball
# 444    6-6   214.0           Colorado   9463484.0  Basketball
# 445    6-6   190.0                NaN   3777720.0  Basketball
# 446   6-10   265.0       Georgia Tech  12000000.0  Basketball
# 447    7-1   245.0                NaN   1175880.0  Basketball
# 448    6-8   226.0             Butler  15409570.0  Basketball
# 449    6-8   206.0               Duke   1348440.0  Basketball
# 450    6-8   226.0                NaN   2050000.0  Basketball
# 451    6-6   206.0             Dayton    981348.0  Basketball
# 452   6-10   234.0           Kentucky   2239800.0  Basketball
# 453    6-3   203.0             Butler   2433333.0  Basketball
# 454    6-1   179.0                NaN    900000.0  Basketball
# 455    7-3   256.0                NaN   2900000.0  Basketball
# 456    7-0   231.0             Kansas    947276.0  Basketball
# 457    NaN     NaN                NaN         NaN  Basketball
#
# [458 rows x 10 columns]

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'League'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-0c26a23f792a> in <module>()
# ----> 1 nba["League"]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'League'

# %%
nba["League"] = "National Basketball Association"

# %%
nba

# %%
nba= pd.read_csv("nba.csv")
nba.head(3)

# %%
nba

# %%
nba.insert(0,column = "new2",value = 8)

# %%
nba.head(3)

# %%
nba.describe()

# %%
nba.head()

# %%
nba.describe()

# %% [markdown]
# ## Broadcasting Operations

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)

# %%
nba["Age"].add(5)

# %%
nba["Age"] + 5

# %%
nba["Salary"].sub(2)

# %%
nba["Salary"] - 10

# %%
nba["Weight_mul_by_4"] = nba["Weight"].mul(4)

# %%
nba.head(3)

# %%
nba["Salary"].div(1000)

# %% [markdown]
# ## value_counts

# %%
nba["Team"].value_counts().head(5)
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# New York Knicks         16
# Milwaukee Bucks         16
# San Antonio Spurs       15
# Name: Team, dtype: int64

# %% [markdown]
# ## Drop Rows with Null Values

# %%
# Drop the row with Null value
nba.dropna()
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# 30             Arron Afflalo         New York Knicks     4.0       SG  30.0
# 31              Lou Amundson         New York Knicks    17.0       PF  33.0
# 33           Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 35          Cleanthony Early         New York Knicks    11.0       SF  25.0
# 36         Langston Galloway         New York Knicks     2.0       SG  24.0
# ..                       ...                     ...     ...      ...   ...
# 422            Cameron Payne   Oklahoma City Thunder    22.0       PG  21.0
# 423           Andre Roberson   Oklahoma City Thunder    21.0       SG  24.0
# 424             Kyle Singler   Oklahoma City Thunder     5.0       SF  28.0
# 425             Dion Waiters   Oklahoma City Thunder     3.0       SG  24.0
# 426        Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 427          Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
#
#     Height  Weight           College      Salary       Sport
# 0      6-2   180.0             Texas   7730337.0  Basketball
# 1      6-6   235.0         Marquette   6796117.0  Basketball
# 3      6-5   185.0     Georgia State   1148640.0  Basketball
# 6      6-8   235.0               LSU   1170960.0  Basketball
# 7      7-0   238.0           Gonzaga   2165160.0  Basketball
# 8      6-2   190.0        Louisville   1824360.0  Basketball
# 9      6-4   220.0    Oklahoma State   3431040.0  Basketball
# 10     6-9   260.0        Ohio State   2569260.0  Basketball
# 11     5-9   185.0        Washington   6912869.0  Basketball
# 12     6-7   220.0        Ohio State   3425510.0  Basketball
# 13     6-6   215.0          Kentucky   1749840.0  Basketball
# 14     7-0   253.0    North Carolina   2616975.0  Basketball
# 16     6-3   190.0    Oklahoma State    845059.0  Basketball
# 17     6-4   200.0    North Carolina   1500000.0  Basketball
# 18     6-7   220.0           Arizona   1335480.0  Basketball
# 19     6-3   200.0      Georgia Tech   6300000.0  Basketball
# 21     6-4   219.0        Cincinnati    134215.0  Basketball
# 22    5-11   175.0        Miami (FL)   1500000.0  Basketball
# 23     7-0   275.0          Stanford  19689000.0  Basketball
# 24    6-11   200.0          Syracuse   1140240.0  Basketball
# 25    6-10   220.0       Saint Louis    947276.0  Basketball
# 26    6-10   237.0            Kansas    981348.0  Basketball
# 27    6-10   248.0        Georgetown    947276.0  Basketball
# 28     6-3   205.0         Texas A&M    947276.0  Basketball
# 29     6-8   221.0      Georgia Tech  11235955.0  Basketball
# 30     6-5   210.0              UCLA   8000000.0  Basketball
# 31     6-9   220.0              UNLV   1635476.0  Basketball
# 33     6-8   240.0          Syracuse  22875000.0  Basketball
# 35     6-8   210.0     Wichita State    845059.0  Basketball
# 36     6-2   200.0    Saint Joseph's    845059.0  Basketball
# ..     ...     ...               ...         ...         ...
# 422    6-3   185.0      Murray State   2021520.0  Basketball
# 423    6-7   210.0          Colorado   1210800.0  Basketball
# 424    6-8   228.0              Duke   4500000.0  Basketball
# 425    6-4   220.0          Syracuse   5138430.0  Basketball
# 426    6-3   200.0              UCLA  16744218.0  Basketball
# 427    6-8   240.0            Kansas    525093.0  Basketball
# 428    6-9   215.0       Wake Forest   8042895.0  Basketball
# 429    6-5   206.0        Notre Dame    625093.0  Basketball
# 430    6-6   210.0        California    947276.0  Basketball
# 431   6-10   240.0    North Carolina   6980802.0  Basketball
# 432    6-9   215.0        St. John's   2894059.0  Basketball
# 433    6-5   215.0              Duke   6000000.0  Basketball
# 434    7-0   265.0  Central Michigan   5016000.0  Basketball
# 435    7-1   245.0          Illinois   3075880.0  Basketball
# 436    6-3   195.0       Weber State   4236287.0  Basketball
# 437    6-4   200.0            Lehigh   2525160.0  Basketball
# 438    6-7   185.0    Westchester CC    525093.0  Basketball
# 439   6-11   235.0              Duke   1415520.0  Basketball
# 440    6-1   173.0            Dayton   2854940.0  Basketball
# 441    6-9   240.0           Indiana   2637720.0  Basketball
# 442    6-8   228.0           Clemson   4775000.0  Basketball
# 443    6-1   191.0          Michigan   2658240.0  Basketball
# 444    6-6   214.0          Colorado   9463484.0  Basketball
# 446   6-10   265.0      Georgia Tech  12000000.0  Basketball
# 448    6-8   226.0            Butler  15409570.0  Basketball
# 449    6-8   206.0              Duke   1348440.0  Basketball
# 451    6-6   206.0            Dayton    981348.0  Basketball
# 452   6-10   234.0          Kentucky   2239800.0  Basketball
# 453    6-3   203.0            Butler   2433333.0  Basketball
# 456    7-0   231.0            Kansas    947276.0  Basketball
#
# [364 rows x 10 columns]

# %%
nba.dropna(how="all")
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 434              Chris Kaman  Portland Trail Blazers    35.0        C  34.0
# 435           Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0
# 436           Damian Lillard  Portland Trail Blazers     0.0       PG  25.0
# 437            C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0
# 438             Luis Montero  Portland Trail Blazers    44.0       SG  23.0
# 439            Mason Plumlee  Portland Trail Blazers    24.0        C  26.0
# 440            Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 441              Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 442            Trevor Booker               Utah Jazz    33.0       PF  28.0
# 443               Trey Burke               Utah Jazz     3.0       PG  23.0
# 444               Alec Burks               Utah Jazz    10.0       SG  24.0
# 445               Dante Exum               Utah Jazz    11.0       PG  20.0
# 446           Derrick Favors               Utah Jazz    15.0       PF  24.0
# 447              Rudy Gobert               Utah Jazz    27.0        C  23.0
# 448           Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 449              Rodney Hood               Utah Jazz     5.0       SG  23.0
# 450               Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451            Chris Johnson               Utah Jazz    23.0       SF  26.0
# 452               Trey Lyles               Utah Jazz    41.0       PF  20.0
# 453             Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 454                Raul Neto               Utah Jazz    25.0       PG  24.0
# 455             Tibor Pleiss               Utah Jazz    21.0        C  26.0
# 456              Jeff Withey               Utah Jazz    24.0        C  26.0
# 457                      NaN                     NaN     NaN      NaN   NaN
#
#     Height  Weight            College      Salary       Sport
# 0      6-2   180.0              Texas   7730337.0  Basketball
# 1      6-6   235.0          Marquette   6796117.0  Basketball
# 2      6-5   205.0  Boston University         NaN  Basketball
# 3      6-5   185.0      Georgia State   1148640.0  Basketball
# 4     6-10   231.0                NaN   5000000.0  Basketball
# 5      6-9   240.0                NaN  12000000.0  Basketball
# 6      6-8   235.0                LSU   1170960.0  Basketball
# 7      7-0   238.0            Gonzaga   2165160.0  Basketball
# 8      6-2   190.0         Louisville   1824360.0  Basketball
# 9      6-4   220.0     Oklahoma State   3431040.0  Basketball
# 10     6-9   260.0         Ohio State   2569260.0  Basketball
# 11     5-9   185.0         Washington   6912869.0  Basketball
# 12     6-7   220.0         Ohio State   3425510.0  Basketball
# 13     6-6   215.0           Kentucky   1749840.0  Basketball
# 14     7-0   253.0     North Carolina   2616975.0  Basketball
# 15     6-8   216.0                NaN   3425510.0  Basketball
# 16     6-3   190.0     Oklahoma State    845059.0  Basketball
# 17     6-4   200.0     North Carolina   1500000.0  Basketball
# 18     6-7   220.0            Arizona   1335480.0  Basketball
# 19     6-3   200.0       Georgia Tech   6300000.0  Basketball
# 20     6-7   208.0                NaN   1599840.0  Basketball
# 21     6-4   219.0         Cincinnati    134215.0  Basketball
# 22    5-11   175.0         Miami (FL)   1500000.0  Basketball
# 23     7-0   275.0           Stanford  19689000.0  Basketball
# 24    6-11   200.0           Syracuse   1140240.0  Basketball
# 25    6-10   220.0        Saint Louis    947276.0  Basketball
# 26    6-10   237.0             Kansas    981348.0  Basketball
# 27    6-10   248.0         Georgetown    947276.0  Basketball
# 28     6-3   205.0          Texas A&M    947276.0  Basketball
# 29     6-8   221.0       Georgia Tech  11235955.0  Basketball
# ..     ...     ...                ...         ...         ...
# 428    6-9   215.0        Wake Forest   8042895.0  Basketball
# 429    6-5   206.0         Notre Dame    625093.0  Basketball
# 430    6-6   210.0         California    947276.0  Basketball
# 431   6-10   240.0     North Carolina   6980802.0  Basketball
# 432    6-9   215.0         St. John's   2894059.0  Basketball
# 433    6-5   215.0               Duke   6000000.0  Basketball
# 434    7-0   265.0   Central Michigan   5016000.0  Basketball
# 435    7-1   245.0           Illinois   3075880.0  Basketball
# 436    6-3   195.0        Weber State   4236287.0  Basketball
# 437    6-4   200.0             Lehigh   2525160.0  Basketball
# 438    6-7   185.0     Westchester CC    525093.0  Basketball
# 439   6-11   235.0               Duke   1415520.0  Basketball
# 440    6-1   173.0             Dayton   2854940.0  Basketball
# 441    6-9   240.0            Indiana   2637720.0  Basketball
# 442    6-8   228.0            Clemson   4775000.0  Basketball
# 443    6-1   191.0           Michigan   2658240.0  Basketball
# 444    6-6   214.0           Colorado   9463484.0  Basketball
# 445    6-6   190.0                NaN   3777720.0  Basketball
# 446   6-10   265.0       Georgia Tech  12000000.0  Basketball
# 447    7-1   245.0                NaN   1175880.0  Basketball
# 448    6-8   226.0             Butler  15409570.0  Basketball
# 449    6-8   206.0               Duke   1348440.0  Basketball
# 450    6-8   226.0                NaN   2050000.0  Basketball
# 451    6-6   206.0             Dayton    981348.0  Basketball
# 452   6-10   234.0           Kentucky   2239800.0  Basketball
# 453    6-3   203.0             Butler   2433333.0  Basketball
# 454    6-1   179.0                NaN    900000.0  Basketball
# 455    7-3   256.0                NaN   2900000.0  Basketball
# 456    7-0   231.0             Kansas    947276.0  Basketball
# 457    NaN     NaN                NaN         NaN  Basketball
#
# [458 rows x 10 columns]

# %%
#column with Null value
nba.dropna(axis = 1)
nba.dropna(axis = "columns")
# Out:
#           Sport
# 0    Basketball
# 1    Basketball
# 2    Basketball
# 3    Basketball
# 4    Basketball
# 5    Basketball
# 6    Basketball
# 7    Basketball
# 8    Basketball
# 9    Basketball
# 10   Basketball
# 11   Basketball
# 12   Basketball
# 13   Basketball
# 14   Basketball
# 15   Basketball
# 16   Basketball
# 17   Basketball
# 18   Basketball
# 19   Basketball
# 20   Basketball
# 21   Basketball
# 22   Basketball
# 23   Basketball
# 24   Basketball
# 25   Basketball
# 26   Basketball
# 27   Basketball
# 28   Basketball
# 29   Basketball
# ..          ...
# 428  Basketball
# 429  Basketball
# 430  Basketball
# 431  Basketball
# 432  Basketball
# 433  Basketball
# 434  Basketball
# 435  Basketball
# 436  Basketball
# 437  Basketball
# 438  Basketball
# 439  Basketball
# 440  Basketball
# 441  Basketball
# 442  Basketball
# 443  Basketball
# 444  Basketball
# 445  Basketball
# 446  Basketball
# 447  Basketball
# 448  Basketball
# 449  Basketball
# 450  Basketball
# 451  Basketball
# 452  Basketball
# 453  Basketball
# 454  Basketball
# 455  Basketball
# 456  Basketball
# 457  Basketball
#
# [458 rows x 1 columns]

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba.dropna(subset = ["Salary","Age"]).head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary       Sport
# 0          Texas  7730337.0  Basketball
# 1      Marquette  6796117.0  Basketball
# 3  Georgia State  1148640.0  Basketball
